# %%
import pandas as pd
df1 = pd.read_csv("alabama_spike.csv", sep=';')
df2 = pd.read_csv("alabama_withoutspike.csv", sep=';')


df_spojene = pd.concat([df1, df2], ignore_index=True)
df_spojene.head(20)
# Out:
#    Year_month    State     State_clearance  Homicide_count  \
# 0     12-1990  Alabama  Alabama Clearances             242
# 1     12-1991  Alabama  Alabama Clearances             258
# 2     12-1992  Alabama  Alabama Clearances             244
# 3     12-1993  Alabama  Alabama Clearances             269
# 4     12-1994  Alabama  Alabama Clearances             275
# 5     12-1995  Alabama  Alabama Clearances             262
# 6     12-1996  Alabama  Alabama Clearances             257
# 7     12-1997  Alabama  Alabama Clearances             312
# 8     12-1998  Alabama  Alabama Clearances             232
# 9     12-1999  Alabama  Alabama Clearances             334
# 10    12-2000  Alabama  Alabama Clearances             205
# 11    12-2001  Alabama  Alabama Clearances             253
# 12    12-2002  Alabama  Alabama Clearances             206
# 13    12-2003  Alabama  Alabama Clearances             215
# 14    12-2004  Alabama  Alabama Clearances             190
# ...

# %%
df_spojene.to_csv("Exectuion_join.csv", sep=';', index=False)
