# %%
import pandas as pd
df = pd.read_csv("Population_part2.csv",encoding="utf-8-sig")
df.head()
# Out:
#    Countyfips State  Year  White Alone  Black Alone  \
# 0           0  U.S.  1990  209366661.0   30648345.0
# 1           0  U.S.  1991  211606011.0   31290743.0
# 2           0  U.S.  1992  213945622.0   31979982.0
# 3           0  U.S.  1993  216187073.0   32634735.0
# 4           0  U.S.  1994  218304774.0   33258981.0
#
#    American Indian or Alaskan Native  Asian Alone  \
# 0                          2058726.0    7549082.0
# 1                          2126968.0    7957219.0
# 2                          2202176.0    8386444.0
# 3                          2282052.0    8814728.0
# 4                          2361078.0    9200988.0
#
#    Hawaiian or Pacific Islander Alone  Two or More Races  Not Hispanic  \
# 0                                 NaN                NaN   227049976.0
# 1                                 NaN                NaN   229425951.0
# 2                                 NaN                NaN   231894879.0
# ...

# %%
df.dtypes
# Out:
# Countyfips                              int64
# State                                  object
# Year                                    int64
# White Alone                           float64
# Black Alone                           float64
# American Indian or Alaskan Native     float64
# Asian Alone                           float64
# Hawaiian or Pacific Islander Alone    float64
# Two or More Races                     float64
# Not Hispanic                          float64
# Hispanic                              float64
# dtype: object

# %%
# seznam sloupců, které chceš převést

cols_to_convert = ['White Alone','Black Alone', 'American Indian or Alaskan Native', 'Asian Alone', 'Hawaiian or Pacific Islander Alone', 'Two or More Races', 'Not Hispanic', 'Hispanic']
df[cols_to_convert] = df[cols_to_convert].astype('Int64')

# %%
df.dtypes
# Out:
# Countyfips                             int64
# State                                 object
# Year                                   int64
# White Alone                            Int64
# Black Alone                            Int64
# American Indian or Alaskan Native      Int64
# Asian Alone                            Int64
# Hawaiian or Pacific Islander Alone     Int64
# Two or More Races                      Int64
# Not Hispanic                           Int64
# Hispanic                               Int64
# dtype: object

# %%
df.to_csv("Population_part2_beznul.csv", sep=';', index=False)
df.head()
# Out:
#    Countyfips State  Year  White Alone  Black Alone  \
# 0           0  U.S.  1990    209366661     30648345
# 1           0  U.S.  1991    211606011     31290743
# 2           0  U.S.  1992    213945622     31979982
# 3           0  U.S.  1993    216187073     32634735
# 4           0  U.S.  1994    218304774     33258981
#
#    American Indian or Alaskan Native  Asian Alone  \
# 0                            2058726      7549082
# 1                            2126968      7957219
# 2                            2202176      8386444
# 3                            2282052      8814728
# 4                            2361078      9200988
#
#    Hawaiian or Pacific Islander Alone  Two or More Races  Not Hispanic  \
# 0                                <NA>               <NA>     227049976
# 1                                <NA>               <NA>     229425951
# 2                                <NA>               <NA>     231894879
# ...
