# %%
import pandas as pd
df = pd.read_csv("States_status_with_codes.csv", sep=";", encoding="utf-8-sig")

# %%
df.head()
# Out:
#   StateCode       State      Status    Year  Last_execution  \
# 0        AL     Alabama      Active     NaN          2024.0
# 1        AK      Alaska   Abolition  1957.0             NaN
# 2        AZ     Arizona      Active     NaN          2025.0
# 3        AR    Arkansas      Active     NaN          2017.0
# 4        CA  California  Moratorium     NaN          2006.0
#
#                       Description
# 0                             NaN
# 1  Zrušeno před přijetím do Unie.
# 2                             NaN
# 3                             NaN
# 4                      Moratorium

# %%
df.dtypes
# Out:
# StateCode          object
# State              object
# Status             object
# Year              float64
# Last_execution    float64
# Description        object
# dtype: object

# %%
cols_to_convert = ["Year", "Last_execution"]

df[cols_to_convert] = df[cols_to_convert].astype("Int64")  
df.head()
# Out:
#   StateCode       State      Status  Year  Last_execution  \
# 0        AL     Alabama      Active  <NA>            2024
# 1        AK      Alaska   Abolition  1957            <NA>
# 2        AZ     Arizona      Active  <NA>            2025
# 3        AR    Arkansas      Active  <NA>            2017
# 4        CA  California  Moratorium  <NA>            2006
#
#                       Description
# 0                             NaN
# 1  Zrušeno před přijetím do Unie.
# 2                             NaN
# 3                             NaN
# 4                      Moratorium

# %%
df.to_csv("States_Status_Final.csv", sep=";", index=False, encoding="utf-8-sig")
